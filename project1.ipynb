# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

with open("users.json", "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)
df.plot.scatter(x=4, y=1)
plt.plot([0, 120000],[120, 150])
