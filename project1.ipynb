# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
# %matplotlib inline

with open("users.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data)
df.plot.scatter(x=1, y=4)
plt.plot([0, 120000],[0, 150])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

X = np.array()
