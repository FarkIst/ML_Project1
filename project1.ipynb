# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

## Exercice 1.1

with open("users.json", "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)
df.plot.scatter(x=1, y=4)

# %% [raw]
# # Exercise 1.2
# Describe with at least two lines of text which model you chose and why:
#
# The data seems to gather around a line between 0 and 20000 on the y axis.
#
# It seems a straight line might describe this data the best.
# Polynomial functions dont seem to fit the data better no matter the degree of the polynomial considered.
#
# For these reasons it seems simple linear regression is indeed the best solution here.

# %%
## Exercise 1.3

import numpy as np
import sklearn 
import sklearn.linear_model
import sklearn.metrics

##We have to drop unused data in order to run model.fit, throws error NaN 
df.dropna(subset=['created','karma','submitted'], inplace = True)

## y = ax + b

xs = df["created"]

actual = df["karma"]

model = sklearn.linear_model.LinearRegression()
xs_reshape = np.array(xs).reshape(9299,1)

model.fit(xs_reshape, actual)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predicted = model.predict(xs_reshape)

plt.scatter(xs, actual)
plt.plot(xs, predicted, color = 'black')

# %% [raw]
# ## Exercise 1.4
# 1. A description of the model parameters:
# Why are they there? What is their purpose in the model?
# We use the points and the time since account created as parameters, and we train the regression model in order to be able to predict based on our existing data.
#
# What do they explain for your data? How are they helping you to predict how much time you need to be active in order to gain Hackernews points?
# Just by looking at the plot we can see that the less time spent means more points accumulated. That is true, but only from 1.20e9 to 1.50e9 time spent. Since we don't have any comparison data we don't know if it will be true outside of this interval.
#
# 2. A visual plot of the model that explains the description above.
# In the case of a linear regression this is a line that shows how the model expects how long a user needs to be active (x value) in order to get a certain number of points (y value).
# Explain: What does it take to get 1000 points? How long would you have to be active on Hackernews?
# Approx 1.46392e9 from our models prediction.

# %%
model.predict([[1.46392e9]])
# Out:
# array([1000.09787207])

# %%
## Exercise 2
import pandas as pd
import json
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

with open("users.json", "r") as f:
    data = json.load(f)
df = pd.DataFrame(data)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df.created, df.submitted, df.karma, zdir='z', s=10, c=None, depthshade=True)
# print(df.karma)
# df.plot(x=1, y=4, z=5)

# %%
### import numpy as np
import sklearn 
import sklearn.linear_model
import sklearn.metrics
from pprint import pprint

##We have to drop unused data in order to run model.fit, throws error NaN 
df.dropna(subset=['created','karma','submitted'], inplace = True)

## y = ax + by + z

xs = np.array(df[["created","submitted"]])

actual = df["karma"]

model = sklearn.linear_model.LinearRegression()
xs_reshape = np.array(xs).reshape(9299,2)

model.fit(xs_reshape, actual)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
predicted = model.predict(xs_reshape)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(df["created"], df["submitted"], predicted, zdir='z', s=10, c=None, depthshade=True)

# %% [raw]
# The model parameters that we’re dealing with are the same parameters we used in the first part of the assignment, apart from the third and new feature “submitted”-column, which is turning the 2-dimensional plot into a 3-dimensional plot.
#
# However now we use “Time” and Number of posts to predict and plot the number of points, in addition to using the predictive value of time.
#
# Though we had trouble making sense out of the undetermined X values from a Y value.
#
# To get 1000 point, the closest approximation we can get is 1.46392e9 for the time parameter, like in the first case, and 443 for the second parameter, number of posts, which is in corelation to what the graph shows as well

# %%
model.predict(np.array([1.46392e9, 443]).reshape(-1,2))
# Out:
# array([1000.31937461])

# %% [raw]
# ## Execise 3
#
# Due to the fact the csv source was down and we did not have access to the dataset, we could not solve this par
